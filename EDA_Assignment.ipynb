# %%
import pandas as pd

# %%
# load the data
data = pd.read_csv("Cardiotocographic.csv")
# Display the first few rows of the dataset
data.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
# Display the information about the dataset
print(f"Data Info: {data.info()}")
# count the number of missing values in each column
# This will help identify if there are any columns with missing data
print(f"Count of Null values:\n {data.isnull().sum()}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB
# Data Info: None
# Count of Null values:
#  LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# ...

# %%
# Calculate the mean and standard deviation of the dataset
# This will give a quick overview of the central tendency and spread of the data
data.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
# Fill missing values with the mean of each column
# This is a common method to handle missing data, especially when the amount of missing data is small
# It helps to maintain the dataset's integrity without losing too much information
data_cleaned = data.fillna(data.mean())
display(data_cleaned.isnull().sum())
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %% [markdown]
# Data Visualization

# %%
# Data Visualization
# Importing necessary libraries for visualization
import matplotlib.pyplot as plt

# Plotting histograms for each column in the dataset
# This will help visualize the distribution of each feature
data_cleaned.hist(figsize=(15, 10),color = "skyblue")
plt.tight_layout()
plt.show()

# %%
# Scatter plots to visualize relationships between pairs of features
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
# scatter plots for some correlated columns
sns.scatterplot(data=data_cleaned, x='ASTV', y='MSTV',color = 'red')
plt.title('Scatter plot of ASTV vs MSTV')
plt.show()

# scatter plot of ALTV vs MLTV
plt.figure(figsize=(8, 6))
sns.scatterplot(data=data_cleaned, x='ALTV', y='MLTV',color = 'skyblue')
plt.title('Scatter plot of ALTV vs MLTV')
plt.show()

# scatter plot of Width vs MSTV
plt.figure(figsize=(8, 6))
sns.scatterplot(data=data_cleaned, x='Width', y='MSTV',color = 'green')
plt.title('Scatter plot of Width vs MSTV')
plt.show()

# %%
# Detect and treat outliers using IQR
# Calculate IQR for each column and identify outliers
# This will help in understanding the spread of the data and identifying potential outliers

import numpy as np
import pandas as pd

outlier_summary = []

for col in data_cleaned.columns:
    q1 = np.percentile(data_cleaned[col], 25) # 25th percentile
    q3 = np.percentile(data_cleaned[col], 75) # 75th percentile
    IQR = q3 - q1  # Interquartile range
    UW = q3 + (1.5 * IQR) # Upper Whisker
    LW = q1 - (1.5 * IQR) # Lower Whisker

    # Count outliers
    num_upper = (data_cleaned[col] > UW).sum() # Count of upper outliers
    num_lower = (data_cleaned[col] < LW).sum() # Count of lower outliers

    # Replace outliers with the whisker values
    # This will help in treating the outliers without removing them from the dataset
    # It ensures that the data remains within a reasonable range
    data_cleaned[col] = np.where(data_cleaned[col] > UW, UW,
                        np.where(data_cleaned[col] < LW, LW, data_cleaned[col]))

    # Collect summary
    # This will help in understanding the spread of the data and identifying outliers
    outlier_summary.append({
        "Column": col,
        "Quartile 1": q1,
        "Quartile 3": q3,
        "IQR": IQR,
        "Lower Whisker": LW,
        "Upper Whisker": UW,
        "Upper Outliers": num_upper,
        "Lower Outliers": num_lower
    })

# displaying the summary table in df
outlier_df = pd.DataFrame(outlier_summary)
display(outlier_df)
# Out:
#       Column  Quartile 1  Quartile 3        IQR  Lower Whisker  Upper Whisker  \
# 0         LB  126.000000  140.000000  14.000000     105.000000     161.000000
# 1         AC    0.000000    0.005606   0.005606      -0.008409       0.014015
# 2         FM    0.000000    0.002567   0.002567      -0.003850       0.006416
# 3         UC    0.001851    0.006536   0.004685      -0.005177       0.013564
# 4         DL    0.000000    0.003289   0.003289      -0.004934       0.008224
# 5         DS    0.000000    0.000000   0.000000       0.000000       0.000000
# 6         DP    0.000000    0.000000   0.000000       0.000000       0.000000
# 7       ASTV   32.000000   61.000000  29.000000     -11.500000     104.500000
# 8       MSTV    0.700000    1.700000   1.000000      -0.800000       3.200000
# 9       ALTV    0.000000   11.000000  11.000000     -16.500000      27.500000
# 10      MLTV    4.600000   10.800000   6.200000      -4.700000      20.100000
# ...

# %%
# Before vs After Outlier Treatment
import matplotlib.pyplot as plt
import seaborn as sns

# ---- BEFORE Treatment ----
fig, axes = plt.subplots(2, 5, figsize=(18,8))
axes = axes.flatten()

# Plotting boxplots for each column to visualize outliers
# This will help identify any outliers in the dataset
for i, col in enumerate(data.columns[:10]):  # first 10 columns
    sns.boxplot(x=data[col], ax=axes[i], color="red") # red for before treatment
    axes[i].set_title(f"{col} (Before Treatment)") # title for each subplot

# Set the title for the entire figure -- y offset to avoid overlap
plt.suptitle("Boxplots (Before Outlier Treatment)", fontsize=16, y=1.02)
plt.tight_layout() # Adjust layout to prevent overlap
plt.show()

# ---- AFTER Treatment ----
fig, axes = plt.subplots(2, 5, figsize=(18,8))
axes = axes.flatten()

for i, col in enumerate(data_cleaned.columns[:10]):  # first 10 columns
    sns.boxplot(x=data_cleaned[col], ax=axes[i], color="green") # green for after treatment
    axes[i].set_title(f"{col} (After Treatment)")

# suptitle for each subplot
plt.suptitle("Boxplots (After Outlier Treatment)", fontsize=16, y=1.02)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Before Outlier Treatment
plt.figure(figsize=(12,8))
# Plotting a heatmap to visualize the correlation matrix
# This will help identify relationships between features
# Annotating the heatmap is set to True to  cluttering with numbers
sns.heatmap(data.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap (Before Outlier Treatment)")
plt.show()

# After Outlier Treatment
plt.figure(figsize=(12,8))
# Plotting a heatmap to visualize the correlation matrix after outlier treatment
sns.heatmap(data_cleaned.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap (After Outlier Treatment)")
plt.show()

# %%
# Before Outlier Treatment
plt.figure(figsize=(18,10))
# Plotting violin plots for the first 6 columns to visualize the distribution of data
# This will help visualize the distribution of the data and identify any potential patterns
for i, col in enumerate(data.columns[:6]):  # first 6 columns to avoid overcrowding
    plt.subplot(2, 3, i+1)
    sns.violinplot(y=data[col], color="red") # skyblue for before treatment
    plt.title(f"Before - {col}")
plt.tight_layout()
plt.show()

# After Outlier Treatment
plt.figure(figsize=(18,10))
# Plotting violin plots for the first 6 columns to visualize the distribution of data after outlier treatment
for i, col in enumerate(data_cleaned.columns[:6]):  # first 6 columns
    plt.subplot(2, 3, i+1)
    sns.violinplot(y=data_cleaned[col], color="green") #` lightgreen for after treatment`
    plt.title(f"After - {col}")
plt.tight_layout()
plt.show()

# %%
# Select a subset of columns
# This will help in visualizing the relationships between specific features
#  we have use "LB", "ASTV", and "MSTV" because they lot of columns in the dataset so we will take only 3 columns

import seaborn as sns
cols = ["LB", "ASTV", "MSTV"]

# Before Outlier Treatment
sns.pairplot(data[cols], diag_kind="kde") # This will help visualize the relationships between the selected features
# diag_kind="kde" will plot kernel density estimates on the diagonal kde --> kernel density estimate
plt.suptitle("Pairplot (Before Outlier Treatment)", y=1.02)
plt.show()

# After Outlier Treatment
# Plotting pairplot for the same columns after outlier treatment
sns.pairplot(data_cleaned[cols], diag_kind="kde")
plt.suptitle("Pairplot (After Outlier Treatment)", y=1.02)
plt.show()

# %% [markdown]
# ### Conclusion
# * The dataset contained several outliers across multiple variables.
# * Outliers were detected using the **IQR method** and treated by capping values at the whiskers.
# * **Before treatment**, violin plots and boxplots showed highly skewed distributions, and correlations were distorted by extreme values.
# * **After treatment**, distributions became smoother, and correlation heatmaps provided more reliable insights.
# * Scatterplots and pairplots highlighted key relationships (e.g., LB vs UC).
# * Overall, preprocessing improved the dataset quality, making it more suitable for further statistical analysis and machine learning models
#
# Overall Insight:
# Variability features (ASTV, MSTV, ALTV, MLTV) show meaningful correlations.
# Outlier treatment helped stabilize distributions.
# These insights can support further modeling and clinical decision-making.
# The analysis provided a clearer understanding of fetal heart rate variability patterns. With cleaned and stabilized data, further steps could include predictive modeling or clinical decision-support systems to better monitor fetal health.
